# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
feature_image=Image.open(r'C:\Users\Hp\Downloads\gratisography-augmented-reality-800x525.jpg')
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x525>

# %%
image_arr=np.asarray(feature_image) #converted to numpy array
image_arr
# Out:
# array([[[21, 29, 32],
#         [19, 27, 30],
#         [18, 26, 29],
#         ...,
#         [17, 22, 25],
#         [18, 23, 26],
#         [20, 25, 28]],
#
#        [[21, 29, 32],
#         [19, 27, 30],
#         [18, 26, 29],
#         ...,
#         [17, 22, 25],
#         [18, 23, 26],
#         [20, 25, 28]],
#
#        [[21, 29, 32],
#         [19, 27, 30],
#         [18, 26, 29],
#         ...,
#         [17, 22, 25],
#         [18, 23, 26],
#         [20, 25, 28]],
#
#        ...,
#
#        [[22, 35, 43],
#         [18, 31, 39],
#         [16, 29, 37],
#         ...,
#         [19, 27, 29],
#         [21, 29, 31],
#         [22, 30, 32]],
#
#        [[22, 35, 43],
#         [18, 31, 39],
#         [16, 29, 37],
#         ...,
#         [19, 27, 29],
#         [21, 29, 31],
#         [22, 30, 32]],
#
#        [[22, 35, 43],
#         [18, 31, 39],
#         [16, 29, 37],
#         ...,
#         [19, 27, 29],
#         [21, 29, 31],
#         [22, 30, 32]]], dtype=uint8)

# %%
plt.imshow(image_arr)
plt.show()

# %%
image_arr. shape #Dimensions of image......
# Out:
# (525, 800, 3)

# %%
image_2= Image.open(r"C:\Users\Hp\Downloads\iStock-487506120-1024x683.jpg")
image_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683>

# %%
imagearr=np.asarray(image_2)
imagearr
# Out:
# array([[[ 76, 103,  58],
#         [ 76, 103,  58],
#         [ 76, 103,  58],
#         ...,
#         [ 82,  99,  47],
#         [ 83, 100,  48],
#         [ 84, 101,  49]],
#
#        [[ 76, 103,  58],
#         [ 76, 103,  58],
#         [ 76, 103,  58],
#         ...,
#         [ 81,  98,  46],
#         [ 82,  99,  47],
#         [ 83, 100,  48]],
#
#        [[ 76, 103,  58],
#         [ 76, 103,  58],
#         [ 76, 103,  58],
#         ...,
#         [ 79,  96,  44],
#         [ 80,  97,  45],
#         [ 81,  98,  46]],
#
#        ...,
#
#        [[ 72,  73,  59],
#         [ 80,  80,  70],
#         [ 96,  99,  92],
#         ...,
#         [ 97, 120,  66],
#         [ 97, 120,  66],
#         [ 97, 120,  66]],
#
#        [[ 75,  76,  62],
#         [ 85,  85,  75],
#         [102, 105,  98],
#         ...,
#         [ 97, 120,  66],
#         [ 97, 120,  66],
#         [ 97, 120,  66]],
#
#        [[ 74,  74,  62],
#         [ 86,  86,  76],
#         [107, 110, 103],
# ...

# %%
 plt.imshow(imagearr)
 plt.show()

# %%
imagearr.shape
# Out:
# (683, 1024, 3)

# %%
image_2= Image.open(r"C:\Users\Hp\Downloads\iStock-487506120-1024x683.jpg")
image_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683>
