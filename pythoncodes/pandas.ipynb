# %% [markdown]
# #  PANDAS--
# - Pandas is the library which handles the data framne .
# - dataframe -
# - pandas use for :---
# - Missing data
# - inserted and deleted coloums from data frame
# - **numpy is array pandas is a table**
# - Data alingment
# - Group by function
# - Easy to convert from onr data type to other data type .
# - slicing ,fancy indexing,subsetting
# - margining & joining
# - Reshaping and pivoting table
# - hierachical (CSV,EXCEL FILE)
# - Time series
# --------------------------------------------
# 1 Excel - dataset
#
# 2 rows * columns
#
# 3 rows - records
#
# 4 columns - feature,variable,attribute,dimension
#
# 5 data set -- either number or text
#
# 6 number-- numerical data
#
# 7 text -- Categorical data
